# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing the dataset

# %%
data=pd.read_csv('C:/Users/Sachin/Desktop/Python/playstore-analysis.csv', engine = 'python')
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite â€“ FREE Live Cool Themes, Hid...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %% [markdown]
# ### Data cleaning:Missing value Clean up
# #### a. Drop records where rating is missing since rating is our target/study variable

# %%
data[pd.isnull(data["Rating"])]
# Out:
#                                                      App             Category  \
# 23                                Mcqueen Coloring pages       ART_AND_DESIGN
# 113                            Wrinkles and rejuvenation               BEAUTY
# 123                               Manicure - nail design               BEAUTY
# 126                         Skin Care and Natural Beauty               BEAUTY
# 129                  Secrets of beauty, youth and health               BEAUTY
# 130                   Recipes and tips for losing weight               BEAUTY
# 134                        Lady adviser (beauty, health)               BEAUTY
# 163                           Anonymous caller detection  BOOKS_AND_REFERENCE
# 180                  SH-02J Owner's Manual (Android 8.0)  BOOKS_AND_REFERENCE
# 185                       URBANO V 02 instruction manual  BOOKS_AND_REFERENCE
# 227                                       Y! Mobile menu             BUSINESS
# ...

# %%
data=data.dropna(subset=['Rating'])
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite â€“ FREE Live Cool Themes, Hid...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %% [markdown]
# ### b. Check the null values for the Android Ver column.

# %%
data[pd.isnull(data['Android Ver'])]
# Out:
#                                            App         Category  Rating  \
# 4453                    [substratum] Vacuum: P  PERSONALIZATION     4.4
# 4490                      Pi Dark [substratum]  PERSONALIZATION     4.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
#
#       Reviews         Size Installs  Type     Price Content Rating  \
# 4453      230  11000.00000   1,000+  Paid     $1.49       Everyone
# 4490      189   2100.00000  10,000+  Free         0       Everyone
# 10472    3.0M  21516.52952     Free     0  Everyone            NaN
#
#                   Genres    Last Updated Current Ver Android Ver
# 4453     Personalization   July 20, 2018         4.4         NaN
# 4490     Personalization  March 27, 2018         1.1         NaN
# 10472  February 11, 2018          1.0.19  4.0 and up         NaN

# %% [markdown]
# #### i. Are all 3 records having the same problem?

# %% [markdown]
# Yes,All the three have the same Problem.

# %% [markdown]
# #### ii. Drop the 3rd record i.e. record for “Life Made WIFI …”

# %%
data.drop(data[ (data['App'] == 'Life Made WI-Fi Touchscreen Photo Frame') & (pd.isnull(data["Android Ver"]))].index , inplace = True)

# %%
data[pd.isnull(data['Android Ver'])]
# Out:
#                          App         Category  Rating Reviews     Size  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4     230  11000.0
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5     189   2100.0
#
#      Installs  Type  Price Content Rating           Genres    Last Updated  \
# 4453   1,000+  Paid  $1.49       Everyone  Personalization   July 20, 2018
# 4490  10,000+  Free      0       Everyone  Personalization  March 27, 2018
#
#      Current Ver Android Ver
# 4453         4.4         NaN
# 4490         1.1         NaN

# %% [markdown]
# #### iii. Replace remaining missing values with the mode

# %%
data['Android Ver']=data['Android Ver'].fillna(data['Android Ver'].mode()[0])

# %%
data['Android Ver'][4453]
# Out:
# '4.1 and up'

# %% [markdown]
# ### c. Current ver – replace with most common value

# %%
data[pd.isnull(data["Current Ver"])]
# Out:
#                                   App            Category  Rating Reviews  \
# 15    Learn To Draw Kawaii Characters      ART_AND_DESIGN     3.2      55
# 1553             Market Update Helper  LIBRARIES_AND_DEMO     4.1   20145
# 6322           Virtual DJ Sound Mixer               TOOLS     4.2    4010
# 7333                      Dots puzzle              FAMILY     4.0     179
#
#          Size    Installs  Type  Price Content Rating            Genres  \
# 15     2700.0      5,000+  Free      0       Everyone      Art & Design
# 1553     11.0  1,000,000+  Free      0       Everyone  Libraries & Demo
# 6322   8700.0    500,000+  Free      0       Everyone             Tools
# 7333  14000.0     50,000+  Paid  $0.99       Everyone            Puzzle
#
#            Last Updated Current Ver Android Ver
# 15         June 6, 2018         NaN  4.2 and up
# 1553  February 12, 2013         NaN  1.5 and up
# 6322       May 10, 2017         NaN  4.0 and up
# ...

# %%
data['Current Ver']=data['Current Ver'].fillna(data['Current Ver'].mode()[0])

# %%
data['Current Ver'][15]
# Out:
# 'Varies with device'

# %% [markdown]
# ## 2. Data clean up – correcting the data types

# %% [markdown]
# ### a. Which all variables need to be brought to numeric types?

# %% [markdown]
# ### Installs
# ### Reviews
# ### Price

# %% [markdown]
# ###  b. Price variable – remove  $ sign and convert to float

# %%
data['Price'] = data['Price'].str.replace(',', '').str.replace('$', '').astype(float)

# %%
data['Price'][235]
# Out:
# 4.99

# %%
data.dtypes['Price']
# Out:
# dtype('float64')

# %% [markdown]
# ### c. Installs – remove ‘,’ and ‘+’ sign, convert to integer

# %%
data['Installs']=data['Installs'].str.replace(',', '').str.replace('+', '').astype(int)

# %%
data['Installs']
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
# 5           50000
# 6           50000
# 7         1000000
# 8         1000000
# 9           10000
# 10        1000000
# 11        1000000
# 12       10000000
# 13         100000
# 14         100000
# 15           5000
# 16         500000
# 17          10000
# 18        5000000
# 19       10000000
# 20         100000
# 21         100000
# 22         500000
# 24          50000
# 25          10000
# 26         500000
# 27         100000
# 28          10000
# 29         100000
# 30         100000
#            ...
# 10795      100000
# 10796     1000000
# 10797     1000000
# 10799      100000
# 10800        5000
# 10801        1000
# 10802       10000
# 10803     1000000
# 10804      100000
# 10805         100
# 10809     1000000
# 10810         100
# 10812        1000
# 10814       50000
# 10815      500000
# 10817      100000
# 10819        5000
# 10820        1000
# 10826     5000000
# ...

# %%
data.dtypes['Installs']
# Out:
# dtype('int32')

# %% [markdown]
# ### d. Convert all other identified columns to numeric

# %%
data['Reviews']=data['Reviews'].astype(int)

# %%
data.dtypes['Reviews']
# Out:
# dtype('int32')

# %% [markdown]
# ### 3. Sanity checks – check for the following and handle accordingly

# %% [markdown]
# ### a. Avg. rating should be between 1 and 5, as only these values are allowed on the play store.
#
# #### i. Are there any such records? Drop if so.

# %%
(data['Rating']< 1).sum()
# Out:
# 0

# %%
(data['Rating'] > 5).sum()
# Out:
# 0

# %% [markdown]
# ### b. Reviews should not be more than installs as only those who installed can review the app.
# #### i. Are there any such records? Drop if so.

# %%
data[data['Reviews'] > data['Installs']]
# Out:
#                                  App   Category  Rating  Reviews         Size  \
# 2454             KBA-EZ Health Guide    MEDICAL     5.0        4  25000.00000
# 4663   Alarmy (Sleep If U Can) - Pro  LIFESTYLE     4.8    10249  21516.52952
# 5917                        Ra Ga Ba       GAME     5.0        2  20000.00000
# 6700                Brick Breaker BR       GAME     5.0        7  19000.00000
# 7402            Trovami se ci riesci       GAME     5.0       11   6100.00000
# 8591                         DN Blog     SOCIAL     5.0       20   4200.00000
# 10697                        Mu.F.O.       GAME     5.0        2  16000.00000
#
#        Installs  Type  Price Content Rating     Genres      Last Updated  \
# 2454          1  Free   0.00       Everyone    Medical    August 2, 2018
# 4663      10000  Paid   2.49       Everyone  Lifestyle     July 30, 2018
# 5917          1  Paid   1.49       Everyone     Arcade  February 8, 2017
# ...

# %%
data.drop(data[data['Reviews'] > data['Installs']].index,inplace=True)

# %%
data[data['Reviews'] > data['Installs']]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# ### 4. Identify and handle outliers –

# %% [markdown]
# ### a. Price column
# ### i. Make suitable plot to identify outliers in price

# %%
import matplotlib.pyplot as plt
plt.boxplot(data['Price'])
plt.show()

# %% [markdown]
# #### ii. Do you expect apps on the play store to cost $200? Check out these cases

# %%
data[data['Price']>200]
# Out:
#                                  App   Category  Rating  Reviews     Size  \
# 4197          most expensive app (H)     FAMILY     4.3        6   1500.0
# 4362                   ðŸ’Ž I'm rich  LIFESTYLE     3.8      718  26000.0
# 4367        I'm Rich - Trump Edition  LIFESTYLE     3.6      275   7300.0
# 5351                       I am rich  LIFESTYLE     3.8     3547   1800.0
# 5354                  I am Rich Plus     FAMILY     4.0      856   8700.0
# 5355                   I am rich VIP  LIFESTYLE     3.8      411   2600.0
# 5356               I Am Rich Premium    FINANCE     4.1     1867   4700.0
# 5357             I am extremely Rich  LIFESTYLE     2.9       41   2900.0
# 5358                      I am Rich!    FINANCE     3.8       93  22000.0
# 5359              I am rich(premium)    FINANCE     3.5      472    965.0
# 5362                   I Am Rich Pro     FAMILY     4.4      201   2700.0
# 5364  I am rich (Most expensive app)    FINANCE     4.1      129   2700.0
# ...

# %% [markdown]
# ## Yes,We can Expect the apps greater than 200

# %% [markdown]
# ### v. Limit data to records with price < $30

# %%
data=data[data['Price'] < 30]
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite â€“ FREE Live Cool Themes, Hid...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %% [markdown]
# ### iii. After dropping the useless records, make the suitable plot again to identify outliers

# %%
plt.boxplot(data['Price'])
plt.show()

# %% [markdown]
# ### b. Reviews column

# %% [markdown]
# ### i. Make suitable plot

# %%
import seaborn as sns
sns.distplot(data['Reviews']);

# %% [markdown]
# #### ii. Limit data to apps with < 1 Million reviews

# %%
(data['Reviews'] > 1000000).sum()
# Out:
# 704

# %%
data=data[data['Reviews'] < 1000000]

# %%
(data['Reviews'] > 1000000).sum()
# Out:
# 0

# %%
sns.distplot(data['Reviews']);

# %% [markdown]
# #### c. Installs
# #####  i. What is the 95th percentile of the installs?

# %%
data['Installs'].quantile(.95)
# Out:
# 10000000.0

# %% [markdown]
# #### ii. Drop records having a value more than the 95th percentile

# %%
data[data['Installs'] > (data['Installs'].quantile(.95))]
# Out:
#                                                      App             Category  \
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 143                                        Amazon Kindle  BOOKS_AND_REFERENCE
# 188                                    Indeed Job Search             BUSINESS
# 192                      Docs To Goâ„¢ Free Office Suite             BUSINESS
# 225                                        Secure Folder             BUSINESS
# 292                      Docs To Goâ„¢ Free Office Suite             BUSINESS
# 346                         imo beta free calls and text        COMMUNICATION
# 348                                             Contacts        COMMUNICATION
# 369                                     Android Messages        COMMUNICATION
# 389                            free video calls and chat        COMMUNICATION
# 396                                     Android Messages        COMMUNICATION
# ...

# %%
data.drop(data[data['Installs'] > data['Installs'].quantile(.95)].index,inplace=True)
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite â€“ FREE Live Cool Themes, Hid...       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters       ART_AND_DESIGN
# ...

# %% [markdown]
# # Data analysis to answer business questions

# %% [markdown]
# ### 5. What is the distribution of ratings like? (use Seaborn) More skewed towards higher/lower values?
# #### a. How do you explain this?

# %%
sns.distplot(data['Rating'])

# %% [markdown]
# #### b. What is the implication of this on your analysis?

# %%
data['Rating'].mode()
# Out:
# 0    4.3
# dtype: float64

# %% [markdown]
# ### 6. What are the top Content Rating values?

# %%
data['Content Rating'].value_counts()
# Out:
# Everyone           6782
# Teen                900
# Mature 17+          417
# Everyone 10+        332
# Adults only 18+       3
# Unrated               1
# Name: Content Rating, dtype: int64

# %% [markdown]
# ### a. Are there any values with very few records?

# %% [markdown]
# Yes,
# ### Unrated
# ### Adults only 18+

# %% [markdown]
# ### b. If yes, drop those as they won’t help in the analysis

# %%
data[(data['Content Rating'] =='Adults only 18+') |  (data['Content Rating']== 'Unrated')]
# Out:
#                                            App Category  Rating  Reviews  \
# 298   Manga Master - Best manga & comic reader   COMICS     4.6    24005
# 3043         DraftKings - Daily Fantasy Sports   SPORTS     4.5    50017
# 6424                               Manga Books   COMICS     3.8     7326
# 8266                    DC Universe Online Map    TOOLS     4.1     1186
#
#              Size  Installs  Type  Price   Content Rating  Genres  \
# 298    4900.00000    500000  Free    0.0  Adults only 18+  Comics
# 3043  41000.00000   1000000  Free    0.0  Adults only 18+  Sports
# 6424  21516.52952    500000  Free    0.0  Adults only 18+  Comics
# 8266   6400.00000     50000  Free    0.0          Unrated   Tools
#
#            Last Updated         Current Ver         Android Ver
# 298        July 4, 2018             1.1.7.0          4.1 and up
# 3043      July 24, 2018            3.21.324          4.4 and up
# 6424     August 3, 2018  Varies with device  Varies with device
# ...

# %%
data.drop(data[(data['Content Rating'] =='Adults only 18+') |  (data['Content Rating']== 'Unrated')].index,inplace=True)

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite â€“ FREE Live Cool Themes, Hid...       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters       ART_AND_DESIGN
# ...

# %% [markdown]
# ### 7. Effect of size on rating

# %% [markdown]
# ### a. Make a joinplot to understand the effect of size on rating

# %%
sns.jointplot(data=data,y='Size',x='Rating')

# %% [markdown]
# ## b. Do you see any patterns?

# %% [markdown]
# Yes, There is co relation between Size,Rating.

# %% [markdown]
# ### c. How do you explain the pattern?

# %% [markdown]
# There is increase in rating when there is increse in Size,but for as the size incresed there is constant ratings

# %% [markdown]
# ### 8. Effect of price on rating

# %% [markdown]
# ##### a. Make a jointplot (with regression line)

# %%
sns.jointplot(data=data,x='Price',y='Rating',kind='reg')

# %% [markdown]
# #### b. What pattern do you see?

# %% [markdown]
# Though thr price increases the ratings remain same around 4

# %% [markdown]
# #### d. Replot the data, this time with only records with price > 0

# %%
data_less=data[data['Price']>0]

# %%
data_less.corr()
# Out:
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.095986  0.117943  0.063960 -0.025975
# Reviews   0.095986  1.000000  0.163959  0.787628 -0.049764
# Size      0.117943  0.163959  1.000000  0.119255  0.024912
# Installs  0.063960  0.787628  0.119255  1.000000 -0.057710
# Price    -0.025975 -0.049764  0.024912 -0.057710  1.000000

# %%
sns.jointplot(data=data_less,x='Price',y='Rating',kind='reg')

# %% [markdown]
# #### e. Does the pattern change?

# %% [markdown]
# There is very weak negetivecorrelation between rating and price after the price fixed greater than 10

# %% [markdown]
# ### f. What is your overall inference on the effect of price on the rating

# %% [markdown]
# There is no significant corelation betn the increase in rating with increase with ratings beacuse the rating is constant around the 4.

# %% [markdown]
# ###  9. Look at all the numeric interactions together –
# #### a. Make a pairplort with the colulmns - 'Reviews', 'Size', 'Rating', 'Price'

# %%
sns.pairplot(data)

# %% [markdown]
# ### 10. Rating vs. content rating
# ### a. Make a bar plot displaying the rating for each content rating

# %%
data.groupby(['Content Rating'])['Rating'].count().plot.bar(color="darkgreen")

# %% [markdown]
# ### b. Which metric would you use? Mean? Median? Some other quantile?

# %% [markdown]
# We must use Median in this case as we are having Outliers in Rating. Because in case of Outliers , median is the best measure of central tendency.

# %% [markdown]
# ## 11. Content rating vs. size vs. rating – 3 variables at a time

# %% [markdown]
# ### a. Create 5 buckets (20% records in each) based on Size
